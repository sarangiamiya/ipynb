# %%
import pandas as pd
import numpy as np

# %%
data = {'X':[78,85,96,80,86], 'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]}
data
# Out:
# {'X': [78, 85, 96, 80, 86],
#  'Y': [84, 94, 89, 83, 86],
#  'Z': [86, 97, 96, 72, 83]}

# %%
dict =pd.DataFrame(data) #OR pd.DataFrame({'X':[78,85,96,80,86], 'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]})
dict
# Out:
#     X   Y   Z
# 0  78  84  86
# 1  85  94  97
# 2  96  89  96
# 3  80  83  72
# 4  86  86  83

# %%
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
exam_data
# Out:
# {'name': ['Anastasia',
#   'Dima',
#   'Katherine',
#   'James',
#   'Emily',
#   'Michael',
#   'Matthew',
#   'Laura',
#   'Kevin',
#   'Jonas'],
#  'score': [12.5, 9, 16.5, nan, 9, 20, 14.5, nan, 8, 19],
#  'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#  'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}

# %%
labels
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
df = pd.DataFrame(data = exam_data, index = labels)
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
print("Summary of the basic information about this DataFrame and its data:")
df.info()
# Out:
# Summary of the basic information about this DataFrame and its data:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
# name        10 non-null object
# score       8 non-null float64
# attempts    10 non-null int64
# qualify     10 non-null object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 280.0+ bytes

# %%
print("First three rows of the data frame:")
df.head(3)
# Out:
# First three rows of the data frame:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes

# %%
print("First three rows of the data frame:")
df.iloc[: 3]
# Out:
# First three rows of the data frame:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes

# %%
print("Select specific columns:")
df[["name", "score"]]
# Out:
# Select specific columns:
#         name  score
# a  Anastasia   12.5
# b       Dima    9.0
# c  Katherine   16.5
# d      James    NaN
# e      Emily    9.0
# f    Michael   20.0
# g    Matthew   14.5
# h      Laura    NaN
# i      Kevin    8.0
# j      Jonas   19.0

# %%
print("Select specific columns and rows:")
df.loc[["b", "d", "f", "g"]][["name", "score"]]
# Out:
# Select specific columns and rows:
#       name  score
# b     Dima    9.0
# d    James    NaN
# f  Michael   20.0
# g  Matthew   14.5

# %%
print("Select specific columns and rows:")
df.loc[['b', 'd', 'f', 'g'], ["name", 'score']]
# Out:
# Select specific columns and rows:
#       name  score
# b     Dima    9.0
# d    James    NaN
# f  Michael   20.0
# g  Matthew   14.5

# %%
print("Select specific columns and rows:")
df.iloc[[1, 3, 5, 6], [0, 1]]
# Out:
# Select specific columns and rows:
#       name  score
# b     Dima    9.0
# d    James    NaN
# f  Michael   20.0
# g  Matthew   14.5

# %%
print("Select specific columns and rows:")
df[df["attempts"] > 2][["name", 'score']]
# Out:
# Select specific columns and rows:
#       name  score
# b     Dima    9.0
# d    James    NaN
# f  Michael   20.0

# %%
print("Number of Rows:", len(df.index))
print("Number of Columns:", len(df.columns) )
# Out:
# Number of Rows: 10
# Number of Columns: 4

# %%
df.keys()
# Out:
# Index(['name', 'score', 'attempts', 'qualify'], dtype='object')

# %%
df.columns
# Out:
# Index(['name', 'score', 'attempts', 'qualify'], dtype='object')

# %%
df.axes[0]
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'], dtype='object')

# %%
df.axes[1]
# Out:
# Index(['name', 'score', 'attempts', 'qualify'], dtype='object')

# %%
print("Rows where score is missing:")
df[df["score"].isnull()]
# Out:
# Rows where score is missing:
#     name  score  attempts qualify
# d  James    NaN         3      no
# h  Laura    NaN         1      no

# %%
print("Rows where score between 15 and 20 (inclusive):")
df[(df["score"] >= 15) & (df["score"] <= 20)]
# Out:
# Rows where score between 15 and 20 (inclusive):
#         name  score  attempts qualify
# c  Katherine   16.5         2     yes
# f    Michael   20.0         3     yes
# j      Jonas   19.0         1     yes

# %%
print("Rows where score between 15 and 20 (inclusive):")
df[df["score"].between(15, 20)]
# Out:
# Rows where score between 15 and 20 (inclusive):
#         name  score  attempts qualify
# c  Katherine   16.5         2     yes
# f    Michael   20.0         3     yes
# j      Jonas   19.0         1     yes

# %%
print("number of attempts in the examination is less than 2 and score greater than 15")
df[(df["attempts"] < 2) & (df["score"] > 15)]
# Out:
# number of attempts in the examination is less than 2 and score greater than 15
#     name  score  attempts qualify
# j  Jonas   19.0         1     yes

# %%
print("Change the score in row 'd' to 11.5: ")
df.loc["d", "score"] = 11.5
df.loc["d"]
# Out:
# Change the score in row 'd' to 11.5:
# name        James
# score        11.5
# attempts        3
# qualify        no
# Name: d, dtype: object

# %%
a = 10
df.loc["d"]
print("After Changing")
df.loc["d", "score"] = a
df.loc["d"]
# Out:
# After Changing
# name        James
# score          10
# attempts        3
# qualify        no
# Name: d, dtype: object

# %%
print("Sum of the examination attempts by the students:")
sum(df["attempts"])
# Out:
# Sum of the examination attempts by the students:
# 19

# %%
print("Sum of the examination attempts by the students:")
df["attempts"].sum()
# Out:
# Sum of the examination attempts by the students:
# 19

# %%
print("Mean score for each different student in data frame: ")
df["score"].mean()
# Out:
# Mean score for each different student in data frame:
# 13.166666666666666

# %%
data1 = {'name' : "Suresh", 'score': 15.5, 'attempts': 1, 'qualify': "yes"}
label1 = ["k"]
df2 = pd.DataFrame(data = data1, index = label1)
print("Before Appending: ")
print(df)

print("Append a new row:")
print("Print all records after insert a new record:")
print(df.append(df2))
# Out:
# Before Appending:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James   10.0         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
# Append a new row:
# Print all records after insert a new record:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James   10.0         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
# ...

# %%
print("Sort the data frame first by 'name' in descending order, then by 'score' in ascending order: ")
df.sort_values(by = ["name", "score"], ascending =[False, True] )
# Out:
# Sort the data frame first by 'name' in descending order, then by 'score' in ascending order:
#         name  score  attempts qualify
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# c  Katherine   16.5         2     yes
# j      Jonas   19.0         1     yes
# d      James   10.0         3      no
# e      Emily    9.0         2      no
# b       Dima    9.0         3      no
# a  Anastasia   12.5         1     yes

# %%
print("Replace the 'qualify' column contains the values 'yes' and 'no' with True and False: ")
df["qualify"].replace(to_replace = ['yes', 'no'], value = ["True", "False"], inplace = True)
df
# Out:
# Replace the 'qualify' column contains the values 'yes' and 'no' with True and False:
#         name  score  attempts qualify
# a  Anastasia   12.5         1    True
# b       Dima    9.0         3   False
# c  Katherine   16.5         2    True
# d      James   10.0         3   False
# e      Emily    9.0         2   False
# f    Michael   20.0         3    True
# g    Matthew   14.5         1    True
# h      Laura    NaN         1   False
# i      Kevin    8.0         2   False
# j      Jonas   19.0         1    True

# %%
df['qualify'] = df['qualify'].map({'yes': True, 'no': False})

# %%
df['qualify']
# Out:
# a     True
# b    False
# c     True
# d    False
# e    False
# f     True
# g     True
# h    False
# i    False
# j     True
# Name: qualify, dtype: bool

# %%
df1 = df[['name', 'qualify']]
df1
# Out:
#         name  qualify
# a  Anastasia     True
# b       Dima    False
# c  Katherine     True
# d      James    False
# e      Emily    False
# f    Michael     True
# g    Matthew     True
# h      Laura    False
# i      Kevin    False
# j      Jonas     True

# %%
df1['qualify'] = df['qualify'].map({True: 'yes',  False: 'no'})
df1
# Out:
# c:\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#         name qualify
# a  Anastasia     yes
# b       Dima      no
# c  Katherine     yes
# d      James      no
# e      Emily      no
# f    Michael     yes
# g    Matthew     yes
# h      Laura      no
# i      Kevin      no
# j      Jonas     yes

# %%
df
# Out:
#         name  score  attempts  qualify
# a  Anastasia   12.5         1     True
# b       Dima    9.0         3    False
# c  Katherine   16.5         2     True
# d      James    NaN         3    False
# e      Emily    9.0         2    False
# f    Michael   20.0         3     True
# g    Matthew   14.5         1     True
# h      Laura    NaN         1    False
# i      Kevin    8.0         2    False
# j      Jonas   19.0         1     True

# %%
print("Change the name 'James' to \?Suresh\?:")
df['name'] = df["name"].replace('James', 'Suresh')
df
# Out:
# Change the name 'James' to \?Suresh\?:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d     Suresh    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
print("Delete the 'attempts' column from the data frame:")
df.drop(labels = 'attempts', axis = 1) #df.pop('attempts') -> completely remove the row
# Out:
# Delete the 'attempts' column from the data frame:
#         name  score qualify
# a  Anastasia   12.5     yes
# b       Dima    9.0      no
# c  Katherine   16.5     yes
# d     Suresh    NaN      no
# e      Emily    9.0      no
# f    Michael   20.0     yes
# g    Matthew   14.5     yes
# h      Laura    NaN      no
# i      Kevin    8.0      no
# j      Jonas   19.0     yes

# %%
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d     Suresh    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
print("New DataFrame after inserting the 'color' column ")
color = ['Red','Blue','Orange','Red','White','White','Blue','Green','Green','Red']
df['color'] = color
df
# Out:
# New DataFrame after inserting the 'color' column
#         name  score  attempts qualify   color
# a  Anastasia   12.5         1     yes     Red
# b       Dima    9.0         3      no    Blue
# c  Katherine   16.5         2     yes  Orange
# d     Suresh    NaN         3      no     Red
# e      Emily    9.0         2      no   White
# f    Michael   20.0         3     yes   White
# g    Matthew   14.5         1     yes    Blue
# h      Laura    NaN         1      no   Green
# i      Kevin    8.0         2      no   Green
# j      Jonas   19.0         1     yes     Red

# %%
color1 = ['Red','Blue','Orange','Red','White','White','Blue','Green','Green','Red']
df.insert(loc = 4, column = 'color1', value = color1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-129-ef6332eac6a8> in <module>
#       1 color1 = ['Red','Blue','Orange','Red','White','White','Blue','Green','Green','Red']
# ----> 2 df.insert(loc = 4, column = 'color1', value = color1)
#       3 df
#
# c:\python37\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3471         value = self._sanitize_column(column, value, broadcast=False)
#    3472         self._data.insert(loc, column, value,
# -> 3473                           allow_duplicates=allow_duplicates)
#    3474
#    3475     def assign(self, **kwargs):
#
# c:\python37\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1147         if not allow_duplicates and item in self.items:
#    1148             # Should this be a different kind of error??
# ...

# %%
df
# Out:
#         name  score  attempts qualify  color1   color
# a  Anastasia   12.5         1     yes     Red     Red
# b       Dima    9.0         3      no    Blue    Blue
# c  Katherine   16.5         2     yes  Orange  Orange
# d     Suresh    NaN         3      no     Red     Red
# e      Emily    9.0         2      no   White   White
# f    Michael   20.0         3     yes   White   White
# g    Matthew   14.5         1     yes    Blue    Blue
# h      Laura    NaN         1      no   Green   Green
# i      Kevin    8.0         2      no   Green   Green
# j      Jonas   19.0         1     yes     Red     Red

# %%
exam_data = [{'name':'Anastasia', 'score':12.5}, {'name':'Dima','score':9}, {'name':'Katherine','score':16.5}]
df = pd.DataFrame(exam_data)
df
# Out:
#         name  score
# 0  Anastasia   12.5
# 1       Dima    9.0
# 2  Katherine   16.5

# %%
for data, values in df.items():
    print(data, " -> ", values)
# Out:
# name  ->  0    Anastasia
# 1         Dima
# 2    Katherine
# Name: name, dtype: object
# score  ->  0    12.5
# 1     9.0
# 2    16.5
# Name: score, dtype: float64

# %%
for index, data in df.iterrows():
    print(index, " -> ", data)
# Out:
# 0  ->  name     Anastasia
# score         12.5
# Name: 0, dtype: object
# 1  ->  name     Dima
# score       9
# Name: 1, dtype: object
# 2  ->  name     Katherine
# score         16.5
# Name: 2, dtype: object

# %%
for index, data in df.iterrows():
    print(data['name'], " -> ", data['score'])
# Out:
# Anastasia  ->  12.5
# Dima  ->  9.0
# Katherine  ->  16.5

# %%
df.columns
# Out:
# Index(['name', 'score', 'attempts', 'qualify'], dtype='object')

# %%
list(df.columns.values)
# Out:
# ['name', 'score', 'attempts', 'qualify']

# %%
df.axes[1]
# Out:
# Index(['name', 'score', 'attempts', 'qualify'], dtype='object')

# %%
d = {'col1': [1, 2, 3], 'col2': [4, 5, 6], 'col3': [7, 8, 9]}
df2 = pd.DataFrame(d)
df2
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9

# %%
df2.columns = ['Column1', 'Column2', 'Column3']
df2
# Out:
#    Column1  Column2  Column3
# 0        1        4        7
# 1        2        5        8
# 2        3        6        9

# %%
df2 = df2.rename(columns = {'col1': 'Column1', 'col2': 'Column2', 'col3': 'Column3'})
df2
# Out:
#    Column1  Column2  Column3
# 0        1        4        7
# 1        2        5        8
# 2        3        6        9

# %%
d3 = {'col1': [1, 4, 3, 4, 5], 'col2': [4, 5, 6, 7, 8], 'col3': [7, 8, 9, 0, 1]}
df3 = pd.DataFrame(data=d3)
df3
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9
# 3     4     7     0
# 4     5     8     1

# %%
df3[df3['col1'] == 4]
# Out:
#    col1  col2  col3
# 1     4     5     8
# 3     4     7     0

# %%
df3.T
# Out:
#       0  1  2  3  4
# col1  1  4  3  4  5
# col2  4  5  6  7  8
# col3  7  8  9  0  1

# %%
df4 = df3[['col3', 'col2', 'col1']]
df4
# Out:
#    col3  col2  col1
# 0     7     4     1
# 1     8     5     4
# 2     9     6     3
# 3     0     7     4
# 4     1     8     5

# %%
l = {'col1': 10, 'col2': 11, 'col3': 12}
#df3.append(l) #TypeError: Can only append a Series if ignore_index=True or if the Series has a name
df3.append(l, ignore_index = True)
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9
# 3     4     7     0
# 4     5     8     1
# 5    10    11    12

# %%
df3.to_csv("new_file.csv", sep='\t', index = False)

# %%
df1 = pd.DataFrame({'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'city': ['California', 'Los Angeles', 'California', 'California', 'California', 'Los Angeles', 'Los Angeles', 'Georgia', 'Georgia', 'Los Angeles']})
df1
# Out:
#         name         city
# 0  Anastasia   California
# 1       Dima  Los Angeles
# 2  Katherine   California
# 3      James   California
# 4      Emily   California
# 5    Michael  Los Angeles
# 6    Matthew  Los Angeles
# 7      Laura      Georgia
# 8      Kevin      Georgia
# 9      Jonas  Los Angeles

# %%
df1['city'].value_counts()
# Out:
# California     4
# Los Angeles    4
# Georgia        2
# Name: city, dtype: int64

# %%
g1 = df1.groupby(["city"]).size().reset_index(name='Number of people')
g1
# Out:
#           city  Number of people
# 0   California                 4
# 1      Georgia                 2
# 2  Los Angeles                 4

# %%
df3
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9
# 3     4     7     0
# 4     5     8     1

# %%
d = {'col1': [1, 4, 3, 4, 5], 'col2': [4, 5, 6, 7, 8], 'col3': [7, 8, 9, 0, 1]}
df3 = pd.DataFrame(data=d)
df3 = df3[df3.col1 != 5]
df3
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9
# 3     4     7     0

# %%
d = {'col1': [1, 4, 3, 4, 5], 'col2': [4, 5, 6, 7, 8], 'col3': [7, 8, 9, 0, 1]}
df = pd.DataFrame(data=d)
df
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9
# 3     4     7     0
# 4     5     8     1

# %%
pd.set_option('display.max_rows', 1500)
pd.set_option('display.max_columns', 1500)
pd.set_option('display.width', 2000)
print("Original DataFrame")
print(df)
# Out:
# Original DataFrame
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9
# 3     4     7     0
# 4     5     8     1

# %%
df.iloc[3]
# Out:
# col1    4
# col2    7
# col3    0
# Name: 3, dtype: int64

# %%
df.iloc[[3]]
# Out:
#    col1  col2  col3
# 3     4     7     0

# %%
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
df = pd.DataFrame(exam_data)
df
# Out:
#         name  score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2  Katherine   16.5         2     yes
# 3      James    NaN         3      no
# 4      Emily    9.0         2      no
# 5    Michael   20.0         3     yes
# 6    Matthew   14.5         1     yes
# 7      Laura    NaN         1      no
# 8      Kevin    8.0         2      no
# 9      Jonas   19.0         1     yes

# %%
df.fillna(value = 0, axis = 1)
# Out:
#         name  score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2  Katherine   16.5         2     yes
# 3      James    0.0         3      no
# 4      Emily    9.0         2      no
# 5    Michael   20.0         3     yes
# 6    Matthew   14.5         1     yes
# 7      Laura    0.0         1      no
# 8      Kevin    8.0         2      no
# 9      Jonas   19.0         1     yes

# %%
df.fillna(0)
# Out:
#         name  score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2  Katherine   16.5         2     yes
# 3      James    0.0         3      no
# 4      Emily    9.0         2      no
# 5    Michael   20.0         3     yes
# 6    Matthew   14.5         1     yes
# 7      Laura    0.0         1      no
# 8      Kevin    8.0         2      no
# 9      Jonas   19.0         1     yes

# %%
df.reset_index(level = 0, inplace = True)
df
# Out:
#    index       name  score  attempts qualify
# 0      0  Anastasia   12.5         1     yes
# 1      1       Dima    9.0         3      no
# 2      2  Katherine   16.5         2     yes
# 3      3      James    NaN         3      no
# 4      4      Emily    9.0         2      no
# 5      5    Michael   20.0         3     yes
# 6      6    Matthew   14.5         1     yes
# 7      7      Laura    NaN         1      no
# 8      8      Kevin    8.0         2      no
# 9      9      Jonas   19.0         1     yes

# %%
print(df.to_string(index = False))
# Out:
#  index       name  score  attempts qualify
#      0  Anastasia   12.5         1     yes
#      1       Dima    9.0         3      no
#      2  Katherine   16.5         2     yes
#      3      James    NaN         3      no
#      4      Emily    9.0         2      no
#      5    Michael   20.0         3     yes
#      6    Matthew   14.5         1     yes
#      7      Laura    NaN         1      no
#      8      Kevin    8.0         2      no
#      9      Jonas   19.0         1     yes

# %%
df.reset_index(level = 0)
# Out:
#    level_0  index       name  score  attempts qualify
# 0        0      0  Anastasia   12.5         1     yes
# 1        1      1       Dima    9.0         3      no
# 2        2      2  Katherine   16.5         2     yes
# 3        3      3      James    NaN         3      no
# 4        4      4      Emily    9.0         2      no
# 5        5      5    Michael   20.0         3     yes
# 6        6      6    Matthew   14.5         1     yes
# 7        7      7      Laura    NaN         1      no
# 8        8      8      Kevin    8.0         2      no
# 9        9      9      Jonas   19.0         1     yes

# %%
#df.iloc[[8, 2]] = 10.2
df.iloc[(8, 1)] = 10.2
df
# Out:
#         name  score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2  Katherine   16.5         2     yes
# 3      James    NaN         3      no
# 4      Emily    9.0         2      no
# 5    Michael   20.0         3     yes
# 6    Matthew   14.5         1     yes
# 7      Laura    NaN         1      no
# 8      Kevin   10.2         2      no
# 9      Jonas   19.0         1     yes

# %%
df.set_value(9, 'score', 20)
# Out:
# c:\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   """Entry point for launching an IPython kernel.
#         name  score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2  Katherine   16.5         2     yes
# 3      James    NaN         3      no
# 4      Emily    9.0         2      no
# 5    Michael   20.0         3     yes
# 6    Matthew   14.5         1     yes
# 7      Laura    NaN         1      no
# 8      Kevin   10.2         2      no
# 9      Jonas   20.0         1     yes

# %%
df.iat[1, 1]
# Out:
# 9.0

# %%
df.iat[1, 0]
# Out:
# 'Dima'

# %%
df.at[1, "score"]
# Out:
# 9.0

# %%
df.at[3, "name"]
# Out:
# 'James'

# %%
df.isnull().values.sum()
# Out:
# 2

# %%
d = {'col1': [1, 4, 3, 4, 5], 'col2': [4, 5, 6, 7, 8], 'col3': [7, 8, 9, 0, 1]}
df = pd.DataFrame(d)
df
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9
# 3     4     7     0
# 4     5     8     1

# %%
df.drop(df.index[[2, 4]])
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 3     4     7     0

# %%
df = pd.DataFrame(np.random.randn(10, 2))
df
# Out:
#           0         1
# 0  1.009897 -1.525091
# 1 -0.243166  0.323346
# 2 -0.296958  1.038726
# 3  1.364091 -0.182610
# 4 -0.247684  0.244027
# 5 -0.230927 -0.131868
# 6  0.934097 -0.466549
# 7 -0.477237 -0.643661
# 8 -0.316560  1.619567
# 9  1.042861  0.591011

# %%
part_70 = df.sample(frac=0.7,random_state=10)
part_70
# Out:
#           0         1
# 8 -0.316560  1.619567
# 2 -0.296958  1.038726
# 5 -0.230927 -0.131868
# 6  0.934097 -0.466549
# 3  1.364091 -0.182610
# 1 -0.243166  0.323346
# 0  1.009897 -1.525091

# %%
part_30 = df.sample(frac=0.3,random_state=10)
part_30
# Out:
#           0         1
# 8 -0.316560  1.619567
# 2 -0.296958  1.038726
# 5 -0.230927 -0.131868

# %%
part_30_1 = df.drop(part_70.index)
part_30_1
# Out:
#           0         1
# 4 -0.247684  0.244027
# 7 -0.477237 -0.643661
# 9  1.042861  0.591011

# %%
part_70.index
# Out:
# Int64Index([8, 2, 5, 6, 3, 1, 0], dtype='int64')

# %%
s1 = pd.Series(['100', '200', 'python', '300.12', '400'])
s2 = pd.Series(['10', '20', 'php', '30.12', '40'])
s1
# Out:
# 0       100
# 1       200
# 2    python
# 3    300.12
# 4       400
# dtype: object

# %%
s2
# Out:
# 0       10
# 1       20
# 2      php
# 3    30.12
# 4       40
# dtype: object

# %%
df = pd.concat([s1, s2], axis = 1)

# %%
df
# Out:
#         0      1
# 0     100     10
# 1     200     20
# 2  python    php
# 3  300.12  30.12
# 4     400     40

# %%
df1 = pd.concat([s1, s2])
df1
# Out:
# 0       100
# 1       200
# 2    python
# 3    300.12
# 4       400
# 0        10
# 1        20
# 2       php
# 3     30.12
# 4        40
# dtype: object

# %%
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
df = pd.DataFrame(exam_data)
df
# Out:
#         name  score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2  Katherine   16.5         2     yes
# 3      James    NaN         3      no
# 4      Emily    9.0         2      no
# 5    Michael   20.0         3     yes
# 6    Matthew   14.5         1     yes
# 7      Laura    NaN         1      no
# 8      Kevin    8.0         2      no
# 9      Jonas   19.0         1     yes

# %%
df.sample(frac = 1)
# Out:
#         name  score  attempts qualify
# 5    Michael   20.0         3     yes
# 3      James    NaN         3      no
# 4      Emily    9.0         2      no
# 9      Jonas   19.0         1     yes
# 2  Katherine   16.5         2     yes
# 0  Anastasia   12.5         1     yes
# 7      Laura    NaN         1      no
# 8      Kevin    8.0         2      no
# 6    Matthew   14.5         1     yes
# 1       Dima    9.0         3      no

# %%
df.sample(n = 5)
# Out:
#         name  score  attempts qualify
# 2  Katherine   16.5         2     yes
# 5    Michael   20.0         3     yes
# 1       Dima    9.0         3      no
# 7      Laura    NaN         1      no
# 4      Emily    9.0         2      no

# %%
s1 = pd.Series(['100', '200', 'python', '300.12', '400'])
s2 = pd.Series(['10', '20', 'php', '30.12', '40'])

# %%
df = pd.concat([s1, s1], axis = 1)
df
# Out:
#         0       1
# 0     100     100
# 1     200     200
# 2  python  python
# 3  300.12  300.12
# 4     400     400

# %%
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
df = pd.DataFrame(exam_data)
df
# Out:
#         name  score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2  Katherine   16.5         2     yes
# 3      James    NaN         3      no
# 4      Emily    9.0         2      no
# 5    Michael   20.0         3     yes
# 6    Matthew   14.5         1     yes
# 7      Laura    NaN         1      no
# 8      Kevin    8.0         2      no
# 9      Jonas   19.0         1     yes

# %%
df = df.sample(frac = 1)
df
# Out:
#         name  score  attempts qualify
# 2  Katherine   16.5         2     yes
# 7      Laura    NaN         1      no
# 5    Michael   20.0         3     yes
# 3      James    NaN         3      no
# 0  Anastasia   12.5         1     yes
# 6    Matthew   14.5         1     yes
# 1       Dima    9.0         3      no
# 4      Emily    9.0         2      no
# 9      Jonas   19.0         1     yes
# 8      Kevin    8.0         2      no

# %%
s = pd.Series(['3/11/2000', '3/12/2000', '3/13/2000'])
s
# Out:
# 0    3/11/2000
# 1    3/12/2000
# 2    3/13/2000
# dtype: object

# %%
r = pd.to_datetime(s)
r
# Out:
# 0   2000-03-11
# 1   2000-03-12
# 2   2000-03-13
# dtype: datetime64[ns]

# %%
df = pd.DataFrame(r)
df
# Out:
#            0
# 0 2000-03-11
# 1 2000-03-12
# 2 2000-03-13

# %%
d = {'col1': [1, 2, 3], 'col2': [4, 5, 6], 'col3': [7, 8, 9]}
df = pd.DataFrame(data=d)
df
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9

# %%
df.rename(columns = {'col2': 'Column2'})
# Out:
#    col1  Column2  col3
# 0     1        4     7
# 1     2        5     8
# 2     3        6     9

# %%
col2 = df["col2"].to_list()
col2
# Out:
# [4, 5, 6]

# %%
dtype = [('Column1','int32'), ('Column2','float32'), ('Column3','float32')]
values = np.zeros(15, dtype=dtype)
index = ['Index'+str(i) for i in range(1, len(values)+1)]
df = pd.DataFrame(values, index=index)
df
# Out:
#          Column1  Column2  Column3
# Index1         0      0.0      0.0
# Index2         0      0.0      0.0
# Index3         0      0.0      0.0
# Index4         0      0.0      0.0
# Index5         0      0.0      0.0
# Index6         0      0.0      0.0
# Index7         0      0.0      0.0
# Index8         0      0.0      0.0
# Index9         0      0.0      0.0
# Index10        0      0.0      0.0
# Index11        0      0.0      0.0
# Index12        0      0.0      0.0
# Index13        0      0.0      0.0
# Index14        0      0.0      0.0
# Index15        0      0.0      0.0

# %%
string = 'Amiya'

# %%
string= string.replace('a','$')
string= string.replace('A','$')
string
# Out:
# '$miy$'

# %%
#Try this manually

a=[['A',34],['B',21],['C',26]]
for i in range(0,len(a)):
    for j in range(0,len(a)-i-1):
        if(a[j][1]>a[j+1][1]):
            temp=a[j]
            a[j]=a[j+1]
            a[j+1]=temp
 
print(a)
# Out:
# [['B', 21], ['C', 26], ['A', 34]]

# %%
#Python Program to sort a list according to the length of the elements

a=[]
n=int(input("Enter number of elements:"))
for i in range(1,n+1):
    b=input("Enter element:")
    a.append(b)
a.sort(key=len)
print(a)

# %%
np.__version__
# Out:
# '1.16.1'

# %%
np.show_config()
# Out:
# blas_mkl_info:
#   NOT AVAILABLE
# blis_info:
#   NOT AVAILABLE
# openblas_info:
#     library_dirs = ['C:\\projects\\numpy-wheels\\numpy\\build\\openblas']
#     libraries = ['openblas']
#     language = f77
#     define_macros = [('HAVE_CBLAS', None)]
# blas_opt_info:
#     library_dirs = ['C:\\projects\\numpy-wheels\\numpy\\build\\openblas']
#     libraries = ['openblas']
#     language = f77
#     define_macros = [('HAVE_CBLAS', None)]
# lapack_mkl_info:
#   NOT AVAILABLE
# openblas_lapack_info:
#     library_dirs = ['C:\\projects\\numpy-wheels\\numpy\\build\\openblas']
#     libraries = ['openblas']
#     language = f77
#     define_macros = [('HAVE_CBLAS', None)]
# lapack_opt_info:
#     library_dirs = ['C:\\projects\\numpy-wheels\\numpy\\build\\openblas']
#     libraries = ['openblas']
#     language = f77
#     define_macros = [('HAVE_CBLAS', None)]

# %%
np.info(np.add)
# Out:
# add(x1, x2, /, out=None, *, where=True, casting='same_kind', order='K', dtype=None, subok=True[, signature, extobj])
#
# Add arguments element-wise.
#
# Parameters
# ----------
# x1, x2 : array_like
#     The arrays to be added.  If ``x1.shape != x2.shape``, they must be
#     broadcastable to a common shape (which may be the shape of one or
#     the other).
# out : ndarray, None, or tuple of ndarray and None, optional
#     A location into which the result is stored. If provided, it must have
#     a shape that the inputs broadcast to. If not provided or `None`,
#     a freshly-allocated array is returned. A tuple (possible only as a
#     keyword argument) must have length equal to the number of outputs.
# where : array_like, optional
#     Values of True indicate to calculate the ufunc at that position, values
#     of False indicate to leave the value in the output alone.
# **kwargs
#     For other keyword-only arguments, see the
#     :ref:`ufunc docs <ufuncs.kwargs>`.
#
# ...

# %%
df = pd.read_excel("coalpublic2013.xls", skiprows = [0, 1, 2])
df.head(2)
# Out:
#    Year  MSHA ID             Mine Name Mine State Mine County  \
# 0  2013   103381  Tacoa Highwall Miner    Alabama        Bibb
# 1  2013   103404      Reid School Mine    Alabama      Blount
#
#                           Mine Status Mine Type                  Company Type  \
# 0  Active, men working, not producing   Surface  Indepedent Producer Operator
# 1               Permanently abandoned   Surface  Indepedent Producer Operator
#
#   Operation Type              Operating Company  \
# 0      Mine only        Jesse Creek Mining, Llc
# 1      Mine only  Taft Coal Sales & Associates,
#
#                            Operating Company Address Union Code  \
# 0            1615 Kent Dairy Rd, Alabaster, AL 35007
# 1  3000 Riverchase Galleria Ste 1, Birmingham, AL...       UNIT
#
#     Coal Supply Region  Production (short tons)  Average Employees  \
# 0  Appalachia Southern                    56004                 10
# 1  Appalachia Southern                    28807                 18
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1450 entries, 0 to 1449
# Data columns (total 16 columns):
# Year                         1450 non-null int64
# MSHA ID                      1450 non-null int64
# Mine Name                    1450 non-null object
# Mine State                   1450 non-null object
# Mine County                  1450 non-null object
# Mine Status                  1450 non-null object
# Mine Type                    1450 non-null object
# Company Type                 1450 non-null object
# Operation Type               1450 non-null object
# Operating Company            1450 non-null object
# Operating Company Address    1450 non-null object
# Union Code                   1450 non-null object
# Coal Supply Region           1450 non-null object
# Production (short tons)      1450 non-null int64
# Average Employees            1450 non-null int64
# Labor Hours                  1450 non-null int64
# dtypes: int64(5), object(11)
# memory usage: 119.0+ KB

# %%
df.dtypes
# Out:
# Year                          int64
# MSHA ID                       int64
# Mine Name                    object
# Mine State                   object
# Mine County                  object
# Mine Status                  object
# Mine Type                    object
# Company Type                 object
# Operation Type               object
# Operating Company            object
# Operating Company Address    object
# Union Code                   object
# Coal Supply Region           object
# Production (short tons)       int64
# Average Employees             int64
# Labor Hours                   int64
# dtype: object

# %%
df1 = pd.read_excel("coalpublic2013.xls", skiprows = [0, 1, 2], usecols= [1, 2, 4])
df1.head(2)
# Out:
#    MSHA ID             Mine Name Mine County
# 0   103381  Tacoa Highwall Miner        Bibb
# 1   103404      Reid School Mine      Blount

# %%
#df.rename(columns = {'Production (short tons)': 'Production'})
print(df["Production (short tons)"].sum())
print(df["Production (short tons)"].max())
print(df["Production (short tons)"].min())
print(df["Production (short tons)"].mean())
# Out:
# 984841779
# 111005549
# 0
# 679201.2268965517

# %%
df.insert(6, "column1", np.nan)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-287a16b952ee> in <module>
# ----> 1 df.insert(6, "column1", np.nan)
#       2 df.head(2)
#
# c:\python37\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3471         value = self._sanitize_column(column, value, broadcast=False)
#    3472         self._data.insert(loc, column, value,
# -> 3473                           allow_duplicates=allow_duplicates)
#    3474
#    3475     def assign(self, **kwargs):
#
# c:\python37\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1147         if not allow_duplicates and item in self.items:
#    1148             # Should this be a different kind of error??
# -> 1149             raise ValueError('cannot insert {}, already exists'.format(item))
#    1150
# ...

# %%
df.head(2)
# Out:
#    Year  MSHA ID             Mine Name Mine State Mine County  \
# 0  2013   103381  Tacoa Highwall Miner    Alabama        Bibb
# 1  2013   103404      Reid School Mine    Alabama      Blount
#
#                           Mine Status  column1 Mine Type  \
# 0  Active, men working, not producing      NaN   Surface
# 1               Permanently abandoned      NaN   Surface
#
#                    Company Type Operation Type              Operating Company  \
# 0  Indepedent Producer Operator      Mine only        Jesse Creek Mining, Llc
# 1  Indepedent Producer Operator      Mine only  Taft Coal Sales & Associates,
#
#                            Operating Company Address Union Code  \
# 0            1615 Kent Dairy Rd, Alabaster, AL 35007
# 1  3000 Riverchase Galleria Ste 1, Birmingham, AL...       UNIT
#
#     Coal Supply Region  Production (short tons)  Average Employees  \
# 0  Appalachia Southern                    56004                 10
# ...

# %%
df2 = pd.read_excel("coalpublic2013.xls", skiprows = 20)
df2.head(2)
# Out:
#    2013  103432                  Skelton Creek  Alabama  Jefferson  \
# 0  2013  103437        Black Warrior Mine No 1  Alabama  Jefferson
# 1  2013  102976  Piney Woods Preparation Plant  Alabama     Shelby
#
#   Temporarily closed  Surface  Indepedent Producer Operator  \
# 0             Active  Surface  Indepedent Producer Operator
# 1             Active  Surface  Indepedent Producer Operator
#
#            Mine only Kennedy Brothers Construction,  \
# 0          Mine only   Black Warrior Minerals, Inc.
# 1  Preparation Plant        Jesse Creek Mining, Llc
#
#      17160 Lock 17 Rd, Brookwood, AL 35444     Appalachia Southern    8252  \
# 0         P.O. Box 1190, Sumiton, AL 35148     Appalachia Southern  145924
# 1  1615 Kent Dairy Rd, Alabaster, AL 35007     Appalachia Southern       0
#
#     3    220
# 0  27  70926
# 1   5  14828

# %%
sum_row = df[["Production (short tons)", "Labor Hours"]].sum()
sum_row
# Out:
# Production (short tons)    984841779
# Labor Hours                177910757
# dtype: int64

# %%
df_sum = pd.DataFrame(data = sum_row).T
df_sum
# Out:
#    Production (short tons)  Labor Hours
# 0                984841779    177910757

# %%
df_sum = df_sum.reindex(columns = df.columns)
df_sum
# Out:
#    Year  MSHA ID  Mine Name  Mine State  Mine County  Mine Status  column1  \
# 0   NaN      NaN        NaN         NaN          NaN          NaN      NaN
#
#    Mine Type  Company Type  Operation Type  Operating Company  \
# 0        NaN           NaN             NaN                NaN
#
#    Operating Company Address  Union Code  Coal Supply Region  \
# 0                        NaN         NaN                 NaN
#
#    Production (short tons)  Average Employees  Labor Hours
# 0                984841779                NaN    177910757

# %%
df_sub = df[["MSHA ID", "Labor Hours"]].groupby("MSHA ID").sum()
df_sub
# Out:
#          Labor Hours
# MSHA ID
# 100329        144002
# 100347        215295
# 100515          6240
# 100759        474784
# 100851       1001809
# 101247       1551141
# 101362        116914
# 101401       2464719
# 102901       1249811
# 102976         38021
# 102996        164093
# 103155         79990
# 103172        119542
# 103179         63745
# 103180        196963
# 103182         87314
# 103195         17411
# 103246         29193
# 103285         90584
# 103303        164388
# 103321         76366
# 103323         46381
# 103332         61394
# 103342        115123
# 103358        161805
# 103364         14324
# 103370           621
# 103372         32401
# 103375          1900
# 103376        176499
# ...              ...
# 4609427        75496
# 4609428        39811
# 4609431         2480
# 4609440        13154
# 4609448        69144
# 4609454        29793
# 4609455        21023
# 4609462         9770
# 4609468        30035
# 4609470        30342
# 4609481         2456
# ...

# %%
df[df["MSHA ID"]==102901].head()
# Out:
#    Year  MSHA ID         Mine Name Mine State Mine County Mine Status  \
# 8  2013   102901  Shoal Creek Mine    Alabama   Jefferson      Active
# 9  2013   102901  Shoal Creek Mine    Alabama   Jefferson      Active
#
#    column1    Mine Type                  Company Type  \
# 8      NaN      Surface  Indepedent Producer Operator
# 9      NaN  Underground  Indepedent Producer Operator
#
#                Operation Type     Operating Company  \
# 8  Mine and Preparation Plant  Drummond Company Inc
# 9  Mine and Preparation Plant  Drummond Company Inc
#
#          Operating Company Address                      Union Code  \
# 8  P.O. Box 1549, Jasper, AL 35501  United Mine Workers of America
# 9  P.O. Box 1549, Jasper, AL 35501  United Mine Workers of America
#
#     Coal Supply Region  Production (short tons)  Average Employees  \
# 8  Appalachia Southern                        0                  5
# 9  Appalachia Southern                  1453024                571
#
# ...

# %%
df[df["Labor Hours"] > 20000].head()
# Out:
#    Year  MSHA ID                       Mine Name Mine State Mine County  \
# 0  2013   103381            Tacoa Highwall Miner    Alabama        Bibb
# 1  2013   103404                Reid School Mine    Alabama      Blount
# 2  2013   100759  North River #1 Underground Min    Alabama     Fayette
# 3  2013   103246                      Bear Creek    Alabama    Franklin
# 4  2013   103451                     Knight Mine    Alabama    Franklin
#
#                           Mine Status  column1    Mine Type  \
# 0  Active, men working, not producing      NaN      Surface
# 1               Permanently abandoned      NaN      Surface
# 2  Active, men working, not producing      NaN  Underground
# 3                              Active      NaN      Surface
# 4                              Active      NaN      Surface
#
#                    Company Type              Operation Type  \
# 0  Indepedent Producer Operator                   Mine only
# ...

# %%
df[df["Mine Name"].map(lambda x: x.startswith('P'))].head(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-95ff232568fa> in <module>
# ----> 1 df[df["Mine Name"].map(lambda x: x.startswith('P'))].head(2)
#
# c:\python37\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    3380         """
#    3381         new_values = super(Series, self)._map_values(
# -> 3382             arg, na_action=na_action)
#    3383         return self._constructor(new_values,
#    3384                                  index=self.index).__finalize__(self)
#
# c:\python37\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#    1216
#    1217         # mapper is a function
# -> 1218         new_values = map_f(values, mapper)
#    1219
#    1220         return new_values
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-39-95ff232568fa> in <lambda>(x)
# ...

# %%
df[df["Mine Name"].map(lambda x: print(x))]
# Out:
# Tacoa Highwall Miner
# Reid School Mine
# North River #1 Underground Min
# Bear Creek
# Knight Mine
# Crane Central Mine
# Concord Mine
# Oak Grove Mine
# Shoal Creek Mine
# Shoal Creek Mine
# Sloan Mountain Mine
# Fishtrap
# Narley Mine
# Powhatan Mine
# Johnson Mine
# Maxine-Pratt Mine
# Skelton Creek
# Black Warrior Mine No 1
# Piney Woods Preparation Plant
# Piney Woods Preparation Plant
# Calera
# Calera
# Clark No 1 Mine
# Helena Surface Mine
# No 4 Mine
# No 7 Mine
# Searles Mine No. 2, 3, 4, 5, 6
# Fleetwood Mine No 1
# Shannon Mine
# Deerlick Mine
# Brc Alabama No. 7 Llc
# Swann's Crossing
# Choctaw Mine
# Manchester Mine
# Jap Creek Mine
# Corinth Prep Plant
# Corinth Prep Plant
# Mccollum/Sparks Branch Mine
# Reese's Branch Mine
# Cresent Valley Mine
# Cane Creek Mine
# Town Creek
# Carbon Hill Mine
# Coal Valley Mine
# Dutton Hill Mine
# Ghm #25
# Poplar Springs
# Old Union
# Usibelli
# Kayenta Mine
# Penny #1
# Sebastian Mine
# Bowie No 2 Mine
# West Elk Mine
# ...

# %%
p = "Tacoa Highwall Miner"
p.startswith('H')
type(p)
' '.join([p, " Hello"])  #Example: '.'.join(['ab', 'pq', 'rs']) -> 'ab.pq.rs'
p.
# Out:
# 'Tacoa Highwall Miner  Hello'

# %%
type(df["Mine Name"])
# Out:
# pandas.core.series.Series

# %%
df[df["Mine Name"].map(lambda x: x.title())] #AttributeError: 'int' object has no attribute 'title'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-de17f9086f15> in <module>
# ----> 1 df[df["Mine Name"].map(lambda x: x.title())]
#
# c:\python37\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    3380         """
#    3381         new_values = super(Series, self)._map_values(
# -> 3382             arg, na_action=na_action)
#    3383         return self._constructor(new_values,
#    3384                                  index=self.index).__finalize__(self)
#
# c:\python37\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#    1216
#    1217         # mapper is a function
# -> 1218         new_values = map_f(values, mapper)
#    1219
#    1220         return new_values
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-73-de17f9086f15> in <lambda>(x)
# ...

# %%
df["Mine Name"]
# Out:
# 0                 Tacoa Highwall Miner
# 1                     Reid School Mine
# 2       North River #1 Underground Min
# 3                           Bear Creek
# 4                          Knight Mine
# 5                   Crane Central Mine
# 6                         Concord Mine
# 7                       Oak Grove Mine
# 8                     Shoal Creek Mine
# 9                     Shoal Creek Mine
# 10                 Sloan Mountain Mine
# 11                            Fishtrap
# 12                         Narley Mine
# 13                       Powhatan Mine
# 14                        Johnson Mine
# 15                   Maxine-Pratt Mine
# 16                       Skelton Creek
# 17             Black Warrior Mine No 1
# 18       Piney Woods Preparation Plant
# 19       Piney Woods Preparation Plant
# 20                              Calera
# 21                              Calera
# 22                     Clark No 1 Mine
# 23                 Helena Surface Mine
# ...

# %%
type(df["Mine Name"].iloc[1429])
# Out:
# str

# %%
df[df["MSHA ID"].isin([102976,103380])]
#df.isin()
# Out:
#     Year  MSHA ID                      Mine Name Mine State Mine County  \
# 18  2013   102976  Piney Woods Preparation Plant    Alabama      Shelby
# 19  2013   102976  Piney Woods Preparation Plant    Alabama      Shelby
# 20  2013   103380                         Calera    Alabama      Shelby
# 21  2013   103380                         Calera    Alabama      Shelby
#
#    Mine Status  column1    Mine Type                  Company Type  \
# 18      Active      NaN      Surface  Indepedent Producer Operator
# 19      Active      NaN  Underground  Indepedent Producer Operator
# 20      Active      NaN      Surface  Indepedent Producer Operator
# 21      Active      NaN  Underground  Indepedent Producer Operator
#
#        Operation Type               Operating Company  \
# 18  Preparation Plant         Jesse Creek Mining, Llc
# 19  Preparation Plant         Jesse Creek Mining, Llc
# 20  Preparation Plant  Conrad Yelvington Distributors
# ...

# %%
df.query('"Mine Name" == ["Shoal Creek Mine", "Piney Woods Preparation Plant"]')
df.query()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-104-509bb5851627> in <module>
# ----> 1 df.query('"Mine Name" == ["Shoal Creek Mine", "Piney Woods Preparation Plant"]')
#       2 df.query()
#
# ...

# %%
df[df["Mine Name"] == "Shoal Creek Mine" ]
# Out:
#    Year  MSHA ID         Mine Name Mine State Mine County Mine Status  \
# 8  2013   102901  Shoal Creek Mine    Alabama   Jefferson      Active
# 9  2013   102901  Shoal Creek Mine    Alabama   Jefferson      Active
#
#    column1    Mine Type                  Company Type  \
# 8      NaN      Surface  Indepedent Producer Operator
# 9      NaN  Underground  Indepedent Producer Operator
#
#                Operation Type     Operating Company  \
# 8  Mine and Preparation Plant  Drummond Company Inc
# 9  Mine and Preparation Plant  Drummond Company Inc
#
#          Operating Company Address                      Union Code  \
# 8  P.O. Box 1549, Jasper, AL 35501  United Mine Workers of America
# 9  P.O. Box 1549, Jasper, AL 35501  United Mine Workers of America
#
#     Coal Supply Region  Production (short tons)  Average Employees  \
# 8  Appalachia Southern                        0                  5
# 9  Appalachia Southern                  1453024                571
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
sorted_by_production = df.sort_values(by = ["Production (short tons)"], ascending = False).head(10)
sorted_by_production["Production (short tons)"].head(10).plot(kind = 'barh')
#plt.show()

# %%
df.columns
# Out:
# Index(['Year', 'MSHA ID', 'Mine Name', 'Mine State', 'Mine County',
#        'Mine Status', 'column1', 'Mine Type', 'Company Type', 'Operation Type',
#        'Operating Company', 'Operating Company Address', 'Union Code',
#        'Coal Supply Region', 'Production (short tons)', 'Average Employees',
#        'Labor Hours'],
#       dtype='object')

# %%
df.head(10).plot(kind = 'bar', figsize = (20, 8))

# %%
df = pd.read_excel("SaleData.xlsx")
df.head(2)
# Out:
#    OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0 2018-01-06     East   Martha  Alexander    Television   95.0      1198.0
# 1 2018-01-23  Central  Hermann     Shelli  Home Theater   50.0       500.0
#
#    Sale_amt
# 0  113810.0
# 1   25000.0

# %%
df1 = pd.pivot_table(df, index = ["Region", "SalesMan"])
df1
# Out:
#                        Sale_amt   Unit_price      Units
# Region  SalesMan
# Central David      28191.000000   724.200000  42.600000
#         John       41338.666667   607.666667  52.000000
#         Luis       41274.600000   690.900000  56.200000
#         Shelli      8424.500000   185.500000  48.250000
#         Sigal      41679.166667   585.500000  57.666667
#         Steven     49922.500000  1023.500000  45.750000
# East    Alexander  29587.875000   529.750000  49.500000
#         Diana      18050.000000   362.500000  62.500000
#         Karen      16068.000000   261.166667  56.666667
# West    Michael    33418.000000   849.000000  44.500000
#         Stephen    22015.750000   512.000000  35.500000

# %%
pd.pivot_table(df, index = ["Region", "Manager"], values = ["Sale_amt"], aggfunc = 'sum')
# Out:
#                  Sale_amt
# Region  Manager
# Central Douglas  124016.0
#         Hermann  365108.5
#         Martha   199690.0
#         Timothy  140955.0
# East    Douglas   48204.0
#         Martha   272803.0
# West    Douglas   66836.0
#         Timothy   88063.0

# %%
pd.pivot_table(df, index = ["Region", "Manager"], values = ["Sale_amt"], aggfunc = np.sum)
# Out:
#                  Sale_amt
# Region  Manager
# Central Douglas  124016.0
#         Hermann  365108.5
#         Martha   199690.0
#         Timothy  140955.0
# East    Douglas   48204.0
#         Martha   272803.0
# West    Douglas   66836.0
#         Timothy   88063.0

# %%
pd.pivot_table(df, index = ["Region", "Manager", "SalesMan"], values = ["Sale_amt"])
# Out:
#                                Sale_amt
# Region  Manager SalesMan
# Central Douglas John       41338.666667
#         Hermann Luis       41274.600000
#                 Shelli      8424.500000
#                 Sigal      41679.166667
#         Martha  Steven     49922.500000
#         Timothy David      28191.000000
# East    Douglas Karen      16068.000000
#         Martha  Alexander  29587.875000
#                 Diana      18050.000000
# West    Douglas Michael    33418.000000
#         Timothy Stephen    22015.750000

# %%
pd.pivot_table(df, index = ["Region", "Manager", "SalesMan"], values = ["Sale_amt"], aggfunc = 'sum')
# Out:
#                            Sale_amt
# Region  Manager SalesMan
# Central Douglas John       124016.0
#         Hermann Luis       206373.0
#                 Shelli      33698.0
#                 Sigal      125037.5
#         Martha  Steven     199690.0
#         Timothy David      140955.0
# East    Douglas Karen       48204.0
#         Martha  Alexander  236703.0
#                 Diana       36100.0
# West    Douglas Michael     66836.0
#         Timothy Stephen     88063.0

# %%
pd.pivot_table(df, index = ["Item"], values = ["Units"])
# Out:
#                   Units
# Item
# Cell Phone    55.600000
# Desk           3.333333
# Home Theater  48.133333
# Television    55.076923
# Video Games   56.428571

# %%
df.head(1)
# Out:
#    OrderDate Region Manager   SalesMan        Item  Units  Unit_price  \
# 0 2018-01-06   East  Martha  Alexander  Television   95.0      1198.0
#
#    Sale_amt
# 0  113810.0

# %%
pd.pivot_table(df, index = ["Region"], values = ["Sale_amt"], aggfunc = 'sum')
# Out:
#          Sale_amt
# Region
# Central  829769.5
# East     321007.0
# West     154899.0
