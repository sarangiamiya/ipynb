# %%
import sys

date=input("Enter the date: ")
dd,mm,yy=date.split('/')
#print(dd,mm,yy)
t_date=7
t_month=1
t_year=2020
dd=int(dd)
mm=int(mm)
yy=int(yy)


if (yy>t_year):
    print("Date is invalid.")
    sys.exit(0)
elif ((yy==2020) and (mm>t_month)):
    print("Date is invalid.")
    sys.exit(0)
elif (yy==t_year and mm== t_month and dd> t_date):
    print("Date is invalid.")
    sys.exit(0)


if(mm==1 or mm==3 or mm==5 or mm==7 or mm==8 or mm==10 or mm==12):
    max1=31
elif(mm==4 or mm==6 or mm==9 or mm==11):
    max1=30
elif(yy%4==0 and yy%100!=0 or yy%400==0):
    max1=29
else:
    max1=28
    
if(mm<1 or mm>12):
    print("Date is invalid.")
elif(dd<1 or dd>max1):
    print("Date is invalid.")
else:
    print("Date is Valid")
# Out:
# Enter the date: 20/2/20204
# Date is invalid.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %%
if (yy<=t_year and mm<= t_month and dd> t_date):
    sys.exit(0)
elif ((yy<=2020) and (mm>t_month)):
    sys.exit(0)
elif (yy>t_year):
    sys.exit(0)

# %%
#%qtconsole
#%tb

# %%
import requests
import getpass
import json
import pandas as pd
from pandas.io.json import json_normalize
import datetime

datai = pd.DataFrame()

auth = (input('Username:'),getpass.getpass())

jql = 'project = HSBCRCTB AND status in (Reopened, Backlog, Blocked, "Awaiting implementation", "Change Request Creation", SCREENING, "ASSIGNED TO ENG", "Engineer Research", "Bank Hold", Scoping, "Waiting for Closure", Prep-Schedule, InProgress-PM, "Requester Contacted") AND "Project type" = RTB AND assignee in (gokbabu) AND "PM Assigned" in (gokbabu) ORDER BY created DESC'

#Get number of issues
initparams = {'jql': jql,'maxResults':0}
r = requests.get('https://jira-eng-rtp1.cisco.com/jira/rest/api/2/issue/166889',auth=auth,params=initparams)
data = json.loads(r.text)

#print("Data = ",data)
#print('Total number of issues is:' + str(data['total']))

for value in range (0,1000,1000):
     jql = jql

#fields='summary,watches,description,priority,labels,assignee,status,creator,report,parent'
fields='summary,watches,description,priority,labels,assignee,status,creator,report,parent,comments'

#print(value)
params = {'startAt':str(value),'expand':"",'include':'*summary','validateQuery':'strict','jql':jql,'maxResults':1000,'fields':fields}
r = requests.get('https://jira-eng-rtp1.cisco.com/jira/rest/api/2/search',auth=auth,params=params)
#print(r)
#print(type(r.text))
paginatedjsonrespIssues = json.loads(r.text)["issues"]
partdatadf = json_normalize(paginatedjsonrespIssues)
#print(type(partdatadf), type(paginatedjsonrespIssues), partdatadf.shape)
#print((partdatadf.head()))

datai = pd.concat((datai,partdatadf))

#dataf = datai.drop(columns=['expand','fields.assignee','fields.assignee.active','fields.assignee.avatarUrls.16x16','fields.assignee.avatarUrls.24x24','fields.assignee.avatarUrls.32x32','fields.assignee.avatarUrls.48x48','fields.assignee.key','fields.assignee.name','fields.assignee.self','fields.assignee.timeZone','fields.creator','fields.creator.active','fields.creator.avatarUrls.16x16','fields.creator.avatarUrls.24x24','fields.creator.avatarUrls.32x32','fields.creator.avatarUrls.48x48','fields.creator.key','fields.creator.name','fields.creator.self','fields.creator.timeZone','fields.labels','fields.priority.iconUrl','fields.priority.id','fields.priority.self','fields.status.description','fields.status.iconUrl','fields.status.id','fields.status.self','fields.status.statusCategory.colorName','fields.status.statusCategory.id','fields.status.statusCategory.key','fields.status.statusCategory.self','fields.watches.isWatching','fields.watches.self','fields.watches.watchCount'])

#dataf.rename(columns = datai.iloc[0])

#datai.to_excel('C:/test2'+'.xlsx',sheet_name='test', #index=False )

datai.to_csv('C:/test2'+'.csv', index=False )

#print(dataf.shape)


print(datai.head())

df = pd.read_csv("C:/test2.csv")
print(df.head()

# %%
import requests
import getpass
import json
import pandas as pd
from pandas.io.json import json_normalize
import datetime

datai = pd.DataFrame()

auth = (input('Username:'),getpass.getpass())

jql = 'project = HSBCRCTB AND status in (Reopened, Backlog, Blocked, "Awaiting implementation", "Change Request Creation", SCREENING, "ASSIGNED TO ENG", "Engineer Research", "Bank Hold", Scoping, "Waiting for Closure", Prep-Schedule, InProgress-PM, "Requester Contacted") AND "Project type" = RTB AND assignee in (gokbabu) AND "PM Assigned" in (gokbabu) ORDER BY created DESC'

#Get number of issues
initparams = {'jql': jql,'maxResults':0}
r = requests.get('https://jira-eng-rtp1.cisco.com/jira/rest/api/2/issue/166889',auth=auth,params=initparams)
data = json.loads(r.text)

for value in range (0,1000,1000):
    jql = jql

fields='summary,watches,description,priority,labels,assignee,status,creator,report,parent,comments'

params = {'startAt':str(value),'expand':"",'include':'*summary','validateQuery':'strict','jql':jql,'maxResults':1000,'fields':fields}
r = requests.get('https://jira-eng-rtp1.cisco.com/jira/rest/api/2/search',auth=auth,params=params)

paginatedjsonrespIssues = json.loads(r.text)["issues"]
partdatadf = json_normalize(paginatedjsonrespIssues)

datai = pd.concat((datai,partdatadf))

datai.to_csv('C:/test2'+'.csv', index=False )

print(datai.head())

df = pd.read_csv("C:/test2.csv")
print(df.head())

# %%
import requests
import getpass
import json
import pandas as pd
from pandas.io.json import json_normalize
import datetime

datai = pd.DataFrame()

#auth = (input('Username:'),getpass.getpass())
auth = ('amsarang', 'LowR1Di1tion&')
#print(auth)

jql = 'project = HSBCRCTB AND status in (Reopened, Backlog, Blocked, "Awaiting implementation", "Change Request Creation", SCREENING, "ASSIGNED TO ENG", "Engineer Research", "Bank Hold", Scoping, "Waiting for Closure", Prep-Schedule, InProgress-PM, "Requester Contacted") AND "Project type" = RTB AND assignee in (gokbabu) AND "PM Assigned" in (gokbabu) ORDER BY created DESC'

#Get number of issues
initparams = {'jql': jql,'maxResults':0}
r = requests.get('https://jira-eng-rtp1.cisco.com/jira/rest/api/2/issue/166889',auth=auth,params=initparams)
data = json.loads(r.text)

for value in range (0,1000,1000):
    jql = jql

fields='summary,watches,description,priority,labels,assignee,status,creator,report,parent,comments'

params = {'startAt':str(value),'expand':"",'include':'*summary','validateQuery':'strict','jql':jql,'maxResults':1000,'fields':fields}
r = requests.get('https://jira-eng-rtp1.cisco.com/jira/rest/api/2/search',auth=auth,params=params)

paginatedjsonrespIssues = json.loads(r.text)["issues"]
partdatadf = json_normalize(paginatedjsonrespIssues)

datai = pd.concat((datai,partdatadf))

datai.to_csv('C:/Users/amsarang/Documents/jira_automation/test2'+'.csv', index=False )

#print(datai.head())

df = pd.read_csv("C:/Users/amsarang/Documents/jira_automation/test2.csv")
#print(df["self"][0], type(df["self"]))

r = requests.get(df["self"][0],auth=auth)
data = json.loads(r.text)
#print(data)
#print(type(data))

print(data.keys())
#print(data["fields"])
print(type(data["fields"]))
#print(data["fields"].keys())
#print(data["fields"]["comment"])
for key,value in data["fields"]["comment"].items():
    print("key = ", key)
    print("values = ", value)

print(type(data["fields"]["comment"]["comments"]))
    
#print(data["fields"]["comment"].keys())
#print(data["fields"]["comment"].keys()["comments"])
#comment_info = data["fields"]["comment"].keys()
#print(comment_info)
#print(comment_info["comments"])
#print(data["fields"]["comment"].keys())
"""
for key,value in data["fields"]["comment"].items():
    print("key = ", key)
    print("value = ", value)
"""
#values = data["fields"]["comment"].values()
#print(values)

#values1 = data["fields"]["comment"]["comments"]
#print(type(values1))

#print(type(data["fields"]["comment"]))
#print(data["fields"]["comment"])
# Out:
# dict_keys(['expand', 'id', 'self', 'key', 'fields'])
# <class 'dict'>
# key =  comments
# values =  []
# key =  maxResults
# values =  0
# key =  total
# values =  0
# key =  startAt
# values =  0
# <class 'list'>
# '\nfor key,value in data["fields"]["comment"].items():\n    print("key = ", key)\n    print("value = ", value)\n'

# %%
import requests
import getpass
import json
import pandas as pd
from pandas.io.json import json_normalize
import datetime
import pandas as pd
import io
import requests

datai = pd.DataFrame()

#auth = (input('Username:'),getpass.getpass())
auth = ('amsarang', 'LowR1Di1tion&')
#print(auth)

jql = 'project = HSBCRCTB AND status in (Reopened, Backlog, Blocked, "Awaiting implementation", "Change Request Creation", SCREENING, "ASSIGNED TO ENG", "Engineer Research", "Bank Hold", Scoping, "Waiting for Closure", Prep-Schedule, InProgress-PM, "Requester Contacted") AND "Project type" = RTB AND assignee in (gokbabu) AND "PM Assigned" in (gokbabu) ORDER BY created DESC'

#Get number of issues
initparams = {'jql': jql,'maxResults':0}
r = requests.get('https://jira-eng-rtp1.cisco.com/jira/rest/api/2/issue/166889',auth=auth,params=initparams)
data = json.loads(r.text)

for value in range (0,1000,1000):
    jql = jql

fields='summary,watches,description,priority,labels,assignee,status,creator,report,parent,comments'

params = {'startAt':str(value),'expand':"",'include':'*summary','validateQuery':'strict','jql':jql,'maxResults':1000,'fields':fields}
r = requests.get('https://jira-eng-rtp1.cisco.com/jira/rest/api/2/search',auth=auth,params=params)

paginatedjsonrespIssues = json.loads(r.text)["issues"]
partdatadf = json_normalize(paginatedjsonrespIssues)

datai = pd.concat((datai,partdatadf))

#print(datai)

datai.to_csv('C:/Users/amsarang/Documents/jira_automation/test2'+'.csv', index=False )

#print(datai.head())

df = pd.read_csv("C:/Users/amsarang/Documents/jira_automation/test2.csv")
#print(df["self"][0], type(df["self"]))
#print(df["self"])
print(len(df["self"]))
#for link in df["self"]:
#    print(link)

print(df["self"][39])
#response = requests.get(df["self"][0], auth=auth, stream="True")
#pd.read_csv(response.text, engine='python')

#pd.read_json(df["self"][0], auth=auth)

#url = df["self"][0]
#print(url)
#s = requests.get(url, auth=auth).content
#ds = pd.read_csv(io.StringIO(s.decode('utf-8')))
#print(ds)

r = requests.get(df["self"][39],auth=auth)
#df_jsn = pd.read_csv(r.raw)

data = json.loads(r.text)
#print(data)
print(type(data))
print(data.keys())

#for key,value in data["fields"]["comment"].items():
#    print("key = ", key)
#    print("values = ", value)

print("comment type = ",type(data["fields"]["comment"]["comments"]))
print("comment type len = ",len(data["fields"]["comment"]["comments"]))

#if "body" in data["fields"]["comment"]["comments"]:
#    print("body is present")

for info in range(len(data["fields"]["comment"]["comments"])):
    print(data["fields"]["comment"]["comments"][info])
    print("********************************")
    if "body" in data["fields"]["comment"]["comments"][info]:
        print("body is present")
        print(data["fields"]["comment"]["comments"][info]["body"])
    print("********************************")

#print(data["fields"]["comment"]["comments"])

#df_json = pd.read_json(r.text)
#print(type(df_json))

#df_json.to_excel('C:/Users/amsarang/Documents/jira_automation/df_json'+'.xlsx',sheet_name='test', index=False )


#print(df_json.index)
#for index in df_json.index:
#    print(index)

#print(df_json.loc["comment"])
# Out:
# 40
# https://jira-eng-rtp1.cisco.com/jira/rest/api/2/issue/166889
# <class 'dict'>
# dict_keys(['expand', 'id', 'self', 'key', 'fields'])
# comment type =  <class 'list'>
# comment type len =  7
# ...

# %% [markdown]
# key =  comments
# values =  [{'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/issue/166889/comment/193062', 'id': '193062', 'author': {'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/user?username=adabas', 'name': 'adabas', 'key': 'adabas', 'emailAddress': 'adabas@cisco.com', 'avatarUrls': {'48x48': 'https://jira-eng-rtp1.cisco.com/jira/secure/useravatar?avatarId=11820', '24x24': 'https://jira-eng-rtp1.cisco.com/jira/secure/useravatar?size=small&avatarId=11820', '16x16': 'https://jira-eng-rtp1.cisco.com/jira/secure/useravatar?size=xsmall&avatarId=11820', '32x32': 'https://jira-eng-rtp1.cisco.com/jira/secure/useravatar?size=medium&avatarId=11820'}, 'displayName': 'Ankush Dabas', 'active': True, 'timeZone': 'Asia/Kolkata'}, 'body': 'pls send assignment mail', 'updateAuthor': {'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/user?username=adabas', 'name': 'adabas', 'key': 'adabas', 'emailAddress': 'adabas@cisco.com', 'avatarUrls': {'48x48': 'https://jira-eng-rtp1.cisco.com/jira/secure/useravatar?avatarId=11820', '24x24': 'https://jira-eng-rtp1.cisco.com/jira/secure/useravatar?size=small&avatarId=11820', '16x16': 'https://jira-eng-rtp1.cisco.com/jira/secure/useravatar?size=xsmall&avatarId=11820', '32x32': 'https://jira-eng-rtp1.cisco.com/jira/secure/useravatar?size=medium&avatarId=11820'}, 'displayName': 'Ankush Dabas', 'active': True, 'timeZone': 'Asia/Kolkata'}, 'created': '2018-10-12T09:03:55.246-0400', 'updated': '2018-10-12T09:03:55.246-0400'}, {'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/issue/166889/comment/206691', 'id': '206691', 'author': {'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/user?username=anreja', 'name': 'anreja', 'key': 'anreja', 'emailAddress': 'anreja@cisco.com', 'avatarUrls': {'48x48': 'https://jira-eng-rtp1.cisco.com/jira/secure/useravatar?avatarId=11816', '24x24': 'https://jira-eng-rtp1.cisco.com/jira/secure/useravatar?size=small&avatarId=11816', '16x16': 'https://jira-eng-rtp1.cisco.com/jira/secure/useravatar?size=xsmall&avatarId=11816', '32x32': 'https://jira-eng-rtp1.cisco.com/jira/secure/useravatar?size=medium&avatarId=11816'},

# %%
subtask = [{'id': '166987', 'key': 'HSBCRCTB-6695', 'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/issue/166987', 'fields': {'summary': 'RtB-2018-2726 | [SHP] HASE Branches WiFi services implementation | UC Task', 'status': {'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/status/13108', 'description': '', 'iconUrl': 'https://jira-eng-rtp1.cisco.com/jira/images/icons/statuses/generic.png', 'name': 'Not Required', 'id': '13108', 'statusCategory': {'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/statuscategory/2', 'id': 2, 'key': 'new', 'colorName': 'blue-gray', 'name': 'To Do'}}, 'priority': {'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/priority/17', 'iconUrl': 'https://jira-eng-rtp1.cisco.com/jira/images/icons/priority_major.gif', 'name': 'Medium', 'id': '17'}, 'issuetype': {'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/issuetype/5', 'id': '5', 'description': 'The sub-task of the issue', 'iconUrl': 'https://jira-eng-rtp1.cisco.com/jira/secure/viewavatar?size=xsmall&avatarId=10516&avatarType=issuetype', 'name': 'Sub-task', 'subtask': True, 'avatarId': 10516}}}, {'id': '166999', 'key': 'HSBCRCTB-6707', 'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/issue/166999', 'fields': {'summary': 'RtB-2018-2726 | [SHP] HASE Branches WiFi services implementation | COPG Task', 'status': {'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/status/10902', 'description': '', 'iconUrl': 'https://jira-eng-rtp1.cisco.com/jira/images/icons/statuses/generic.png', 'name': 'COMPLETED', 'id': '10902', 'statusCategory': {'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/statuscategory/3', 'id': 3, 'key': 'done', 'colorName': 'green', 'name': 'Done'}}, 'priority': {'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/priority/17', 'iconUrl': 'https://jira-eng-rtp1.cisco.com/jira/images/icons/priority_major.gif', 'name': 'Medium', 'id': '17'}, 'issuetype': {'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/issuetype/5', 'id': '5', 'description': 'The sub-task of the issue', 'iconUrl': 'https://jira-eng-rtp1.cisco.com/jira/secure/viewavatar?size=xsmall&avatarId=10516&avatarType=issuetype', 'name': 'Sub-task', 'subtask': True, 'avatarId': 10516}}}, {'id': '167020', 'key': 'HSBCRCTB-6728', 'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/issue/167020', 'fields': {'summary': 'RtB-2018-2726 | [SHP] HASE Branches WiFi services implementation | B&C Task', 'status': {'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/status/10902', 'description': '', 'iconUrl': 'https://jira-eng-rtp1.cisco.com/jira/images/icons/statuses/generic.png', 'name': 'COMPLETED', 'id': '10902', 'statusCategory': {'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/statuscategory/3', 'id': 3, 'key': 'done', 'colorName': 'green', 'name': 'Done'}}, 'priority': {'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/priority/17', 'iconUrl': 'https://jira-eng-rtp1.cisco.com/jira/images/icons/priority_major.gif', 'name': 'Medium', 'id': '17'}, 'issuetype': {'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/issuetype/5', 'id': '5', 'description': 'The sub-task of the issue', 'iconUrl': 'https://jira-eng-rtp1.cisco.com/jira/secure/viewavatar?size=xsmall&avatarId=10516&avatarType=issuetype', 'name': 'Sub-task', 'subtask': True, 'avatarId': 10516}}}, {'id': '167042', 'key': 'HSBCRCTB-6750', 'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/issue/167042', 'fields': {'summary': 'RtB-2018-2726 | [SHP] HASE Branches WiFi services implementation | WiFi Task', 'status': {'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/status/12316', 'description': 'This was auto-generated by JIRA Service Desk during workflow import', 'iconUrl': 'https://jira-eng-rtp1.cisco.com/jira/images/icons/status_generic.gif', 'name': 'Work in progress', 'id': '12316', 'statusCategory': {'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/statuscategory/4', 'id': 4, 'key': 'indeterminate', 'colorName': 'yellow', 'name': 'In Progress'}}, 'priority': {'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/priority/17', 'iconUrl': 'https://jira-eng-rtp1.cisco.com/jira/images/icons/priority_major.gif', 'name': 'Medium', 'id': '17'}, 'issuetype': {'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/issuetype/5', 'id': '5', 'description': 'The sub-task of the issue', 'iconUrl': 'https://jira-eng-rtp1.cisco.com/jira/secure/viewavatar?size=xsmall&avatarId=10516&avatarType=issuetype', 'name': 'Sub-task', 'subtask': True, 'avatarId': 10516}}}]

# %%
subtask
# Out:
# [{'id': '166987',
#   'key': 'HSBCRCTB-6695',
#   'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/issue/166987',
#   'fields': {'summary': 'RtB-2018-2726 | [SHP] HASE Branches WiFi services implementation | UC Task',
#    'status': {'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/status/13108',
#     'description': '',
#     'iconUrl': 'https://jira-eng-rtp1.cisco.com/jira/images/icons/statuses/generic.png',
#     'name': 'Not Required',
#     'id': '13108',
#     'statusCategory': {'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/statuscategory/2',
#      'id': 2,
#      'key': 'new',
#      'colorName': 'blue-gray',
#      'name': 'To Do'}},
#    'priority': {'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/priority/17',
#     'iconUrl': 'https://jira-eng-rtp1.cisco.com/jira/images/icons/priority_major.gif',
#     'name': 'Medium',
#     'id': '17'},
#    'issuetype': {'self': 'https://jira-eng-rtp1.cisco.com/jira/rest/api/2/issuetype/5',
# ...

# %%
type(subtask)
# Out:
# list

# %%
subtask["subtask"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-1014b1430706> in <module>
# ----> 1 subtask["subtask"]
#
# TypeError: list indices must be integers or slices, not str
